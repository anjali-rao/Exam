# %% [markdown]
# #### Using functions, numpy and matplotlib to represent data

# %%
import random
import numpy
import matplotlib.pyplot as plt

# %% [markdown]
# Imports random function to generate random numbers

# %%
#numpy.set_printoptions(threshold='nan')
random_matrix = numpy.array(numpy.random.random((100,100)) )

# %% [markdown]
# Creating a 10x10 matrix with random values from 1 to 50

# %%
print random_matrix
x = 11
# Out:
# [[ 0.45654282  0.60156755  0.10531044 ...,  0.94273111  0.1968222
#    0.66486982]
#  [ 0.70398458  0.97231939  0.6441534  ...,  0.71161436  0.04879116
#    0.88056377]
#  [ 0.22635058  0.35869758  0.99997095 ...,  0.45172991  0.5969279
#    0.85298816]
#  ...,
#  [ 0.72202281  0.37907872  0.64051849 ...,  0.25362186  0.88550831
#    0.06829926]
#  [ 0.63350393  0.09168249  0.32120112 ...,  0.95511899  0.45792555
#    0.14447747]
#  [ 0.3759374   0.52590789  0.62859464 ...,  0.04237501  0.44049127
#    0.57531682]]

# %%
def sum_of_rows(random_matrix):
    SumOfRows = [sum(e) for e in random_matrix]
    print SumOfRows

# %% [markdown]
# A function to find the sum of all rows in a matrix

# %%
sum_of_rows(random_matrix)
# Out:
# [53.096004166802913, 52.504428561009625, 47.893211278571165, 46.766174535734891, 50.191373888483284, 48.540213702201697, 50.383580233371397, 48.518924266266438, 49.561188504063608, 52.608473183027243, 51.747086789059431, 46.463888150380214, 48.971903951333594, 53.442586871814299, 52.68743208996397, 46.877046156159963, 53.152326636288286, 47.301762879796357, 50.589997494872584, 45.665921790902161, 50.028464253222168, 50.908432851005514, 47.637570682532456, 52.305236508089031, 48.472183520453221, 47.766246171798905, 50.44882346025328, 50.358215722528122, 49.314070439148978, 45.278406166979146, 48.883248781702747, 49.584982915718328, 48.666068850268047, 49.492140059962693, 51.933641879680415, 54.581863940094451, 45.890362420516944, 50.917929854022759, 45.115092985581398, 49.855646936463657, 49.547282897105219, 44.41257117429673, 48.828421769927253, 47.552267984815551, 53.046081531422956, 46.201101770352444, 48.06195928283833, 48.818728228340035, 48.952087246169853, 49.223968590084965, 4
# ...

# %% [markdown]
# A call to the sum_of_rows function

# %%
#plt.scatter(random_matrix[:,0],random_matrix[:,1],15, c = 'r')
plt.matshow(random_matrix)
plt.colorbar()
plt.title("RANDOM MATRIX")
plt.xlabel("ROW")
plt.ylabel("COLUMN")
plt.show()
